# %% [markdown]
# # 不同亮度下红点的坐标

# %% [markdown]
# 看看屏幕在同样的纯红下（RGB：255,0,0），不同的亮度条件测出来的光谱有无变化

# %% [markdown]
# ## 导入6组红光数据，生成光谱类实例

# %%
import os
os.getcwd()
# Out:
# '/home/edward/Documents/Major/jupyter_notebooks'

# %%
os.chdir('..')
os.getcwd()
# Out:
# '/home/edward/Documents/Major'

# %%
lst = [x for x in os.listdir('./spec_info/2018_10_05/') if x.startswith('green')]
lst.sort()
print(lst)
# Out:
# ['green1_2018_10_05_16_39_00.sp', 'green2_2018_10_05_16_43_31.sp', 'green3_2018_10_05_16_46_55.sp', 'green4_2018_10_05_16_51_36.sp', 'green5_2018_10_05_16_55_02.sp', 'green6_2018_10_05_16_57_22.sp']

# %%
lst = [os.path.join('/home/edward/Documents/Major/spec_info/2018_10_05/', x) for x in lst]
print(lst)
# Out:
# ['/home/edward/Documents/Major/spec_info/2018_10_05/green1_2018_10_05_16_39_00.sp', '/home/edward/Documents/Major/spec_info/2018_10_05/green2_2018_10_05_16_43_31.sp', '/home/edward/Documents/Major/spec_info/2018_10_05/green3_2018_10_05_16_46_55.sp', '/home/edward/Documents/Major/spec_info/2018_10_05/green4_2018_10_05_16_51_36.sp', '/home/edward/Documents/Major/spec_info/2018_10_05/green5_2018_10_05_16_55_02.sp', '/home/edward/Documents/Major/spec_info/2018_10_05/green6_2018_10_05_16_57_22.sp']

# %%
from spectool import *
# Out:
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: "x" independent variable is not uniform, unpredictable results may occur!
#   warn(*args, **kwargs)

# %%
os.getcwd()
# Out:
# '/home/edward/Documents/Major'

# %%
green1 = Spectrum(lst[0], 'green1')
green2 = Spectrum(lst[1], 'green2')
green3 = Spectrum(lst[2], 'green3')
green4 = Spectrum(lst[3], 'green4')
green5 = Spectrum(lst[5], 'green5')
green6 = Spectrum(lst[4], 'green6')
spec_list = [green1, green2, green3, green4, green5, green6]
# Out:
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: "domain" and "range" variables have different size, "range" variable will be resized to "domain" variable shape!
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "D65" illuminant shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green1" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green2" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green3" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green4" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green5" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)
# /home/edward/anaconda3/envs/python-colour/lib/python3.6/site-packages/colour/utilities/verbose.py:141: ColourWarning: Aligning "green6" spectral power distribution shape to "CIE 1931 2 Degree Standard Observer" colour matching functions shape.
#   warn(*args, **kwargs)

# %% [markdown]
# ## 显示他们的亮度

# %%
L_lst = []
for spec in spec_list:
    L_lst.append(spec.get('L'))
    print(spec.name, "|", spec.get('L'), 'cd/m2')
# Out:
# green1 | 10.320598 cd/m2
# green2 | 25.676975 cd/m2
# green3 | 58.32892 cd/m2
# green4 | 90.04072 cd/m2
# green5 | 160.18323 cd/m2
# green6 | 231.12743 cd/m2

# %% [markdown]
# ## 亮度变化可视化

# %%
from pyecharts import Bar

# %%
attr = ['green1', 'green2', 'green3', 'green4', 'green5', 'green6']
bar = Bar("亮度变化", "六个红点样本的亮度")
bar.add("亮度值（cd/m2）", attr, L_lst, is_label_show=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0c571dca56b04c979a5eb3276ac71c60" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0c571dca56b04c979a5eb3276ac71c60 = echarts.init(document.getElementById('0c571dca56b04c979a5eb3276ac71c60'), 'light', {renderer: 'canvas'});
#
# var option_0c571dca56b04c979a5eb3276ac71c60 = {
#     "title": [
#         {
#             "text": "\u4eae\u5ea6\u53d8\u5316",
#             "subtext": "\u516d\u4e2a\u7ea2\u70b9\u6837\u672c\u7684\u4eae\u5ea6",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3020348,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4eae\u5ea6\u503c\uff08cd/m2\uff09",
#             "data": [
#                 10.320598,
#                 25.676975,
#                 58.32892,
#                 90.04072,
#                 160.18323,
#                 231.12743
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3020348
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4eae\u5ea6\u503c\uff08cd/m2\uff09"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "green1",
#                 "green2",
#                 "green3",
#                 "green4",
#                 "green5",
#                 "green6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0c571dca56b04c979a5eb3276ac71c60.setOption(option_0c571dca56b04c979a5eb3276ac71c60);
#
#     });
# </script>

# %% [markdown]
# ## 显示样本的xy坐标

# %%
data = {
    'green1': {'x': green1.x,'y': green1.y}, 
    'green2': {'x': green2.x,'y': green2.y}, 
    'green3': {'x': green3.x,'y': green3.y}, 
    'green4': {'x': green4.x,'y': green4.y}, 
    'green5': {'x': green5.x,'y': green5.y}, 
    'green6': {'x': green6.x,'y': green6.y}, 
}
spec_xy = pd.DataFrame(data).T
print(spec_xy)
# Out:
#                x         y
# green1  0.213339  0.722153
# green2  0.213397  0.724191
# green3  0.213340  0.724570
# green4  0.213583  0.724839
# green5  0.214717  0.723265
# green6  0.215210  0.722776

# %%
spec_xy.loc[:,'x'].values
# Out:
# array([0.21333909, 0.21339707, 0.21333987, 0.21358347, 0.21471703,
#        0.21521042])

# %%
from pyecharts import Line

# %%
v1 = list(spec_xy.loc[:,'x'].values)
v2 = list(spec_xy.loc[:,'y'].values)
attr = [str(x) for x in L_lst]
line = Line("白点随亮度变化的坐标变化")
line.add("x", attr, v1,mark_line=['average'])
line.add("y", attr, v2,mark_line=['average'])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e5dc0d679f084e25b7b32ffbdc3a7dee" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e5dc0d679f084e25b7b32ffbdc3a7dee = echarts.init(document.getElementById('e5dc0d679f084e25b7b32ffbdc3a7dee'), 'light', {renderer: 'canvas'});
#
# var option_e5dc0d679f084e25b7b32ffbdc3a7dee = {
#     "title": [
#         {
#             "text": "\u767d\u70b9\u968f\u4eae\u5ea6\u53d8\u5316\u7684\u5750\u6807\u53d8\u5316",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8999366,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "x",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "3.5855823",
#                     0.67828345
#                 ],
#                 [
#                     "9.3692",
#                     0.68279
#                 ],
#                 [
#                     "21.210852",
#                     0.6832648
#                 ],
#                 [
#                     "32.74512",
#                     0.68342876
#                 ],
#                 [
#                     "59.661057",
#                     0.6832473
#                 ],
#                 [
#                     "87.77652",
#                     0.6825819
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 8999366
#         },
#         {
#             "type": "line",
#             "name": "y",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "3.5855823",
#                     0.31113255
#                 ],
#                 [
#                     "9.3692",
#                     0.3111384
#                 ],
#                 [
#                     "21.210852",
#                     0.31139952
#                 ],
#                 [
#                     "32.74512",
#                     0.31173706
#                 ],
#                 [
#                     "59.661057",
#                     0.31253684
#                 ],
#                 [
#                     "87.77652",
#                     0.313387
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 8999366
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "x",
#                 "y"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "3.5855823",
#                 "9.3692",
#                 "21.210852",
#                 "32.74512",
#                 "59.661057",
#                 "87.77652"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",

# %% [markdown]
# ## **结论：** 可以看出亮度基本不对红点坐标造成影响, 6个样本的x，y值的平均值分别为（0.68, 0.31）

# %% [markdown]
# ## 将六个红点样本绘制在CIE1931图上

# %%
spcs_in_one_diagram(*spec_list)

# %% [markdown]
# ## 总结： 在后续的实验研究过程中，白点坐标取值（0.68, 0.31），不考虑亮度对其坐标值的影响

# %% [markdown]
# 附：各个样本的光谱（可以看出，除了纵坐标有变化，能量值变大，图形基本一致）

# %%
for spec in spec_list:
    spec.spd_plot()
