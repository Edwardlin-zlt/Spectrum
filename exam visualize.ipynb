# %%
import specparse
import os

# %%
files = [x for x in os.listdir('spectral') if os.path.splitext(x)[1]=='.sp']
files = sorted(files)
print(files)
# Out:
# ['blue 1_2018_09_05_19_47_45.sp', 'blue 2_2018_09_05_19_48_13.sp', 'blue 3_2018_09_05_19_48_34.sp', 'green1_2018_09_05_19_46_19.sp', 'green2_2018_09_05_19_46_39.sp', 'green3_2018_09_05_19_47_00.sp', 'red1_2018_09_05_19_44_52.sp', 'red2_2018_09_05_19_45_15.sp', 'red3_2018_09_05_19_45_32.sp', 'white1_2018_09_05_19_42_49.sp', 'white2_2018_09_05_19_44_00.sp', 'white3_2018_09_05_19_44_17.sp']

# %%
for spec_file in files:
    spec_data = specparse.get_spec('spectral/'+spec_file)
    specparse.single_spd_plotting(spec_data, spec_file.split('_')[0])
